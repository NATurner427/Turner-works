# %% [markdown]
# ## Final version pitch timestamper
#
# This is the working version of the pitch timestamper. I have different working versions and iterations in the sandbox notebook.
#
# This routine takes in a image of the score infographic and finds it via template matching for each frame of the video.
# The video is over 3 hours long. To cut down on processing time only one frame is grabbed per second of video.
# After earch pitch is thrown, the top of the infographic is altered to report the speed of the pitch, this is used as the trigger to timestamp for a pitch.
# A p that is obscured by the speed is what a second template match is focused on. When it is obscured the program logs the time.
# Tesseract is used to then pull the pitcher name and pitch count from the infographic. This info is used to match up with the baseball savant logs that were pulled that have the type of pitch and outcome of each pitch reported. By joining the two logs, I will have pitch type and outcome connected to the timestamp of each pitch visual and audio.
#
#
# Some tinkering will be requried for every video I use. Hopefully minimal when it comes to tesseract. But I can for see day versus night games forcing changes to the image processing parameters.
#
# Second, this program was written using a fox sports broadcast. Different broadcasts have different infographics. Differnt infographics mean different ways to trigger the timestamp. Again the hope is they will be minimal. Fox sports has deals with I believe a vast majority of regular season broadcasting rights. One I can think of is Yankees YES network will be different, but I checked and it also flashes the speed of each pitch after its thrown and can be used as a trigger.

# %%
# %%time
#MONITOR PROCESSING TIME


#IMPORT LIBRARIES
try:
    from PIL import Image
except ImportError:
    import Image

import cv2
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

import numpy as np
import pandas as pd


path='E://HOU18/World series 2017/games/game 7/'



#INITIALIZE VARIABLES
h=0
#count instances of finding a pitch and save info in list
got=0
lst=[]

vertex_x=[]
vertex_y=[]

#loop variable how many consecutive frames is the pitch count p being detected and how many frames is required before grabbing info
consecutive=0
threshold=4

# frames to skip per loop
n=0
skip=30

# config options for tesseract
pitchconfig="-l eng --psm 8 --oem 3 -c tessedit_char_blacklist=!@#$%^&*()_-+=|\<>:;{}[]|\,.?/1234567890"
countconfig='-l eng --psm 8 --oem 3 -c tessedit_char_whitelist=0123456789'

#IMPORT TEMPLATES AND GRAB DIMENSIONS
box = cv2.imread('E:/HOU18/snapshots/full box.jpg')  
height, width,chan = box.shape

p=cv2.imread('E:/HOU18/snapshots/pitch p.jpg') 
height_p, width_p,chan = p.shape

#IMPORT VIDEO
cap = cv2.VideoCapture(f'{path}game 7 video.mp4')


if cap.isOpened()== False: 
    print("Error opening the video file. Please double check your file path for typos")

## FIRST LOOP FINDS INFOGRAPHIC POSITION
cap.set(cv2.CAP_PROP_POS_FRAMES, 44000)
while cap.isOpened():
      
    
    #frame skip to middle of game where infographic will be 30 frame per second, say we want to go to 15minutes into the game
    #15*60*30 =27000
    
    
    # Read a new frame
    ret, frame = cap.read()

    #check if frame grab was a success
    if ret == True and cap.get(cv2.CAP_PROP_POS_FRAMES)<44900:
        
        # FIND INFOGRAPHIC AND MAKE VERTICIES FOR RECTANGLE
        res = cv2.matchTemplate(frame,box,cv2.TM_CCOEFF_NORMED)
        min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(res)
        
        top_left=max_val
        
        top_left = max_loc
        bottom_right = (top_left[0] + width, top_left[1] + height)
        
        cv2.rectangle(frame,top_left, bottom_right,(0,200,200), 3)
        
        vertex_x.append(max_loc[0])
        vertex_y.append(max_loc[1])
        
                #DISPLAY FRAME
        cv2.imshow('frame', frame)
        
        # Exit if ESC pressed
        k = cv2.waitKey(1) & 0xff
        if k == 27 : 
            break
            
    else:
        break
 
#TIDY UP
cap.release()
cv2.destroyAllWindows()


#collect top left vertex position of template match for each frame. The value that occurs most often should be our fixed pixel.
pixel_x = max(set(vertex_x), key = vertex_x.count)
pixel_y = max(set(vertex_y), key = vertex_y.count) 

print(pixel_x)
print(pixel_y)
# Out:
# 1014
# 499
# Wall time: 1min 43s

# %%
# %%time
#MONITOR PROCESSING TIME

#IMPORT LIBRARIES
try:
    from PIL import Image
except ImportError:
    import Image

import datetime
import re
import cv2
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

import numpy as np
import pandas as pd

#INITIALIZE VARIABLES
miss=0
#count instances of finding a pitch and save info in list
got=0
lst=[]

pixel_x=1014
pixel_y=499

#loop variable how many consecutive frames is the pitch count p being detected and how many frames is required before grabbing info
consecutive=0
threshold=4

# frames to skip per loop
n=0
skip=30



# config options for tesseract
pitchconfig="-l eng --psm 8 --oem 3 -c tessedit_char_blacklist=!@#$%^&*()_-+=|\<>:;{}[]|\,.?/1234567890ю"
countconfig='-l eng --psm 8 --oem 3 -c tessedit_char_whitelist=0123456789'

#IMPORT TEMPLATES AND GRAB DIMENSIONS
box = cv2.imread('E:/HOU18/snapshots/full box.jpg')  
height, width,chan = box.shape

p=cv2.imread('E:/HOU18/snapshots/pitch p.jpg') 
height_p, width_p,chan = p.shape


path='E://HOU18/World series 2017/games/game 7/'

#IMPORT VIDEO
cap = cv2.VideoCapture(f'{path}game 7 video.mp4')

if cap.isOpened()== False: 
    print("Error opening the video file. Please double check your file path for typos")

    
while cap.isOpened():
    
    #frame skip
    cap.set(cv2.CAP_PROP_POS_FRAMES, n)
    
    # Read a new frame
    ret, frame = cap.read()
    
    #check if frame grab was a success
    if ret == True:
        
        cropFrameInfographic= frame[pixel_y:(pixel_y+height),pixel_x:(pixel_x+width)]
        
        #convert frame to RGB for tesseract
        tessFrame = cv2.cvtColor(cropFrameInfographic, cv2.COLOR_BGR2RGB)
        
        #FIND PITCH COUNT P IN INFOGRAPHIC AND MAKE VERTICIES FOR RECTANGLE
        res_p =cv2.matchTemplate(cropFrameInfographic,p,cv2.TM_CCOEFF_NORMED)
        min_val_p, max_val_p, min_loc_p, max_loc_p = cv2.minMaxLoc(res_p)
        
        top_left_p = max_loc_p
        bottom_right_p = (top_left_p[0] + width_p, top_left_p[1] + height_p) 
        
        
        #DETECT P IN CORRECT LOCATION
        if top_left_p[0] >= 139 and top_left_p[0] <=154 and top_left_p[1] >= 0 and top_left_p[1] <=33:
            consecutive+=1

            #DRAW INFOGRAPHIC AND P BOX RECTANGLES
            #P BOX
            cv2.rectangle(cropFrameInfographic,top_left_p, (bottom_right_p[0]-10,bottom_right_p[1]),(0,255,0), 1)

            # if consecutive frames have the p in correct location extract info
            if consecutive==threshold:
                miss+=1
                #DRAW RECTANGLES
                #PITCHER
                cv2.rectangle(cropFrameInfographic,(0,0),(top_left_p[0],bottom_right_p[1]),(255,80,80), 3)
                #PITCH COUNT
                cv2.rectangle(cropFrameInfographic,(bottom_right_p[0]-10,top_left_p[1]-10),(width,bottom_right_p[1]),(80,80,255), 1)

                #REPORT PITCH RECORDED
                cv2.putText(cropFrameInfographic, "pitch recorded", (0,200), cv2.FONT_HERSHEY_SIMPLEX, 1,(0,255,0),2)

                # GRAB PITCHER IMAGE

                cropFramePitcher= tessFrame[top_left_p[1]:bottom_right_p[1],10:top_left_p[0]]

                #PROCESS PITCHER IMAGE
                cropFramePitcher= cv2.cvtColor(cropFramePitcher, cv2.COLOR_BGR2GRAY)

                scale=1200
                w = int(cropFramePitcher.shape[1] * scale / 100)
                h = int(cropFramePitcher.shape[0] * scale/ 100)
                dim = (w, h)
                cropFramePitcher=cv2.resize(cropFramePitcher,dim,cv2.INTER_AREA)

                r,cropFramePitcher=cv2.threshold(cropFramePitcher, 130, 255, cv2.THRESH_BINARY_INV)

                cropFramePitcher=cv2.medianBlur(cropFramePitcher,15)

                #GRAB PITCH COUNT IMAGE
                cropFrameCount= tessFrame[top_left_p[1]:bottom_right_p[1],bottom_right_p[0]-2:width]

                #PROCESS PITCH COUNT IMAGE
                cropFrameCount= cv2.cvtColor(cropFrameCount, cv2.COLOR_BGR2GRAY)

                w = int(cropFrameCount.shape[1] * scale / 100)
                h = int(cropFrameCount.shape[0] * scale/ 100)
                dim = (w, h)
                cropFrameCount=cv2.resize(cropFrameCount,dim,cv2.INTER_AREA)

                r,cropFrameCount=cv2.threshold(cropFrameCount, 130, 255, cv2.THRESH_BINARY_INV)

                cropFrameCount=cv2.medianBlur(cropFrameCount,15)

                #CALL TESSERACT TO CONVERT IMAGE OF TEXT TO STRING

                pitcher=pytesseract.image_to_string(cropFramePitcher,config=pitchconfig)

                count=pytesseract.image_to_string(cropFrameCount,config=countconfig)

                pitcher=(re.sub('[^A-Za-z]+', '', pitcher))
                #OUTPUT RESULT
                print(f'Pitcher: {pitcher} Pitch Count: {count}')

                #SHOW IMAGES
                cv2.imshow('Pitcher',cropFramePitcher)
                cv2.imshow('Count',cropFrameCount)

                #COLLECT INFO ON FRAME
                got+=1
                t=cap.get(cv2.CAP_PROP_POS_MSEC)
                t=int(np.floor(t/1000))

                if count == '':
                    lst.append([int(got),pitcher,f'miss{miss}',t])
                else:
                    lst.append([int(got),pitcher,count,t])
            # PERSIST THE BOXES PAST THRESHOLD
            elif consecutive > threshold:

                #cv2.rectangle(frame,top_left_p, bottom_right_p,(0,255,0), 1)

                #DRAW RECTANGLES
                #PITCHER
                cv2.rectangle(cropFrameInfographic,(0,0),(top_left_p[0],bottom_right_p[1]),(255,80,80), 3)
                #PITCH COUNT
                cv2.rectangle(cropFrameInfographic,(bottom_right_p[0]-10,top_left_p[1]-10),(width,bottom_right_p[1]),(80,80,255), 1)


                cv2.putText(cropFrameInfographic, "pitch recorded", (0,200), cv2.FONT_HERSHEY_SIMPLEX, 1,(0,255,0),2)

        # P NOT DETECTED RESETS COUNTER
        else:
            consecutive=0

        #DISPLAY FRAME
        cv2.imshow('frame', cropFrameInfographic)
        
        # Exit if ESC pressed
        k = cv2.waitKey(1) & 0xff
        if k == 27 : 
            break
            
    # EXIT IF FAIL TO FIND FRAME
    else:
        break
    
    #FRAME SKIP ITERATOR
    n= n+skip
    
#TIDY UP
cap.release()
cv2.destroyAllWindows()

#WRITE INFO TO DATAFRAME
df=pd.DataFrame(lst,columns =['Pitch number','Pitcher','Pitch Count','time'])
df=df[~df.duplicated(subset=['Pitcher','Pitch Count'],keep='first')]

df.to_csv(f'{path}pitch timelog.csv',index=False)
# Out:
# Pitcher: Darvish Pitch Count: 1
# Pitcher: Darvish Pitch Count: 2
# Pitcher: Darvish Pitch Count: 3
# Pitcher: Darvish Pitch Count: 3
# Pitcher: Darvish Pitch Count: 4
# Pitcher: Darvish Pitch Count: 5
# Pitcher: Danish Pitch Count: 6
# Pitcher: Darvish Pitch Count: 7
# Pitcher: Darvish Pitch Count: 7
# Pitcher: Darvish Pitch Count: 8
# Pitcher: Darvish Pitch Count: 8
# Pitcher: Darvish Pitch Count: 9
# Pitcher: Darvish Pitch Count: 10
# Pitcher: Darvish Pitch Count: 11
# Pitcher: Darvish Pitch Count: 11
# Pitcher: Darvish Pitch Count: 12
# Pitcher: Darvish Pitch Count: 13
# Pitcher: Darvish Pitch Count: 14
# Pitcher: Darvish Pitch Count: 14
# Pitcher: Darvish Pitch Count: 150
# Pitcher: Darvish Pitch Count: 16
# Pitcher: Darvish Pitch Count: 16
# Pitcher: Darvish Pitch Count: 17
# Pitcher: Darvish Pitch Count: 18
# Pitcher: Darvish Pitch Count: 18
# Pitcher: Darvish Pitch Count: 19
# Pitcher: Darvish Pitch Count: 19
# Pitcher: Darvish Pitch Count: 20
# Pitcher: Darvish Pitch Count: 21
# Pitcher: Darvish Pitch Count: 21
# Pitcher: Darvish Pitch Count: 220
# Pitcher: Darvish Pitch Count: 23
# Pitcher: McCullers Pitch Count: 1
# Pitcher: McCullers Pitch Count: 2
# Pitcher: McCullers Pitch Count: 3
# Pitcher: McCullers Pitch Count: 3
# Pitcher: McCullers Pitch Count: 4
# Pitcher: McCullers Pitch Count: 5
# Pitcher: McCullers Pitch Count: 6
# Pitcher: McCullers Pitch Count: 7
# Pitcher: McCullers Pitch Count: 8
# Pitcher: McCullers Pitch Count: 9
# Pitcher: McCullers Pitch Count: 9
# Pitcher: McCullers Pitch Count: 10
# Pitcher: McCullers Pitch Count: 11
# Pitcher: McCullers Pitch Count: 11
# Pitcher: McCullers Pitch Count: 12
# Pitcher: McCullers Pitch Count: 13
# Pitcher: McCullers Pitch Count: 13
# Pitcher: McCullers Pitch Count: 14
# Pitcher: McCullers Pitch Count: 14
# Pitcher: McCullers Pitch Count: 15
# Pitcher: McCullers Pitch Count: 16
# Pitcher: McCullers Pitch Count: 16
# Pitcher: McCullers Pitch Count: 17
# Pitcher: McCullers Pitch Count: 17
# Pitcher: McCullers Pitch Count: 18
# Pitcher: McCullers Pitch Count: 19
# Pitcher: McCullers Pitch Count: 20
# Pitcher: McCullers Pitch Count: 20
# Pitcher: McCullers Pitch Count: 21
# Pitcher: McCullers Pitch Count: 22
# Pitcher: McCullers Pitch Count: 22
# Pitcher: McCullers Pitch Count: 23
# Pitcher: McCullers Pitch Count: 24
# Pitcher: Darvish Pitch Count: 24
# Pitcher: Darvish Pitch Count: 25
# Pitcher: Darvish Pitch Count: 26
# Pitcher: Darvish Pitch Count: 27
# Pitcher: Darvish Pitch Count: 28
# Pitcher: Darvish Pitch Count: 290
# Pitcher: Darvish Pitch Count: 30
# Pitcher: Darvish Pitch Count: 31
# Pitcher: Darvish Pitch Count: 32
# Pitcher: Darvish Pitch Count: 33
# Pitcher: Darvish Pitch Count: 33
# Pitcher: Darvish Pitch Count: 34
# Pitcher: Darvish Pitch Count: 35
# Pitcher: Darvish Pitch Count: 36
# Pitcher: Darvish Pitch Count: 36
# Pitcher: Darvish Pitch Count: 36
# Pitcher: Morrow Pitch Count: 1
# Pitcher: Darvish Pitch Count: 38
# Pitcher: Darvish Pitch Count: 39
# Pitcher: Darvish Pitch Count: 40
# Pitcher: Darvish Pitch Count: 40
# Pitcher: Darvish Pitch Count: 41
# Pitcher: Darvish Pitch Count: 41
# Pitcher: Darvish Pitch Count: 42
# Pitcher: Darvish Pitch Count: 43
# Pitcher: Darvish Pitch Count: 44
# Pitcher: Darvish Pitch Count: 45
# Pitcher: Darwish Pitch Count: 45
# Pitcher: Darvish Pitch Count: 46
# Pitcher: Darvish Pitch Count: 47
# Pitcher: Morrow Pitch Count: 1
# Pitcher: Morrow Pitch Count: 2
# Pitcher: McCullers Pitch Count: 25
# Pitcher: McCullers Pitch Count: 26
# Pitcher: McCullers Pitch Count: 27
# Pitcher: McCullers Pitch Count: 27
# Pitcher: McCullers Pitch Count: 28
# Pitcher: McCullers Pitch Count: 28
# Pitcher: McCullers Pitch Count: 290
# Pitcher: McCullers Pitch Count: 30
# Pitcher: McCullers Pitch Count: 31
# Pitcher: McCullers Pitch Count: 31
# Pitcher: McCullers Pitch Count: 32
# Pitcher: McCullers Pitch Count: 320
# Pitcher: McCullers Pitch Count: 33
# Pitcher: McCullers Pitch Count: 34
# Pitcher: McCullers Pitch Count: 35
# Pitcher: McCullers Pitch Count: 36
# Pitcher: McCullers Pitch Count: 37
# Pitcher: McCullers Pitch Count: 37
# Pitcher: Kershaw Pitch Count: 1
# Pitcher: Kershaw Pitch Count: 2
# Pitcher: Kershaw Pitch Count: 2
# Pitcher: Kershaw Pitch Count: 3
# Pitcher: Kershaw Pitch Count: 3
# Pitcher: Kershaw Pitch Count: 4
# Pitcher: Kershaw Pitch Count: 5
# Pitcher: Kershaw Pitch Count: 6
# Pitcher: Kershaw Pitch Count: 7
# Pitcher: Kershaw Pitch Count: 8
# Pitcher: Kershaw Pitch Count: 8
# Pitcher: Kershaw Pitch Count: 9
# Pitcher: McCullers Pitch Count: 39
# Pitcher: McCullers Pitch Count: 40
# Pitcher: McCullers Pitch Count: 41
# Pitcher: McCullers Pitch Count: 420
# Pitcher: McCullers Pitch Count: 43
# Pitcher: McCullers Pitch Count: 43
# Pitcher: McCullers Pitch Count: 44
# Pitcher: McCullers Pitch Count: 44
# Pitcher: McCullers Pitch Count: 44
# Pitcher: McCullers Pitch Count: 45
# Pitcher: McCullers Pitch Count: 46
# Pitcher: McCullers Pitch Count: 47
# Pitcher: McCullers Pitch Count: 48
# Pitcher: McCullers Pitch Count: 48
# Pitcher: McCullers Pitch Count: 49
# Pitcher: Peacock Pitch Count: 1
# Pitcher: Peacock Pitch Count: 2
# Pitcher: Peacock Pitch Count: 3
# Pitcher: Peacock Pitch Count: 3
# Pitcher: Peacock Pitch Count: 4
# Pitcher: Peacock Pitch Count: 5
# Pitcher: Peacock Pitch Count: 6
# Pitcher: Peacock Pitch Count: 6
# Pitcher: Peacock Pitch Count: 7
# Pitcher: Peacock Pitch Count: 7
# Pitcher: Kershaw Pitch Count: 11
# Pitcher: Kershaw Pitch Count: 120
# Pitcher: Kershaw Pitch Count: 13
# Pitcher: Kershaw Pitch Count: 14
# Pitcher: Kershaw Pitch Count: 14
# Pitcher: Kershaw Pitch Count: 150
# Pitcher: Kershaw Pitch Count: 16
# Pitcher: Kershaw Pitch Count: 17
# Pitcher: Kershaw Pitch Count: 18
# Pitcher: Kershaw Pitch Count: 18
# Pitcher: Kershaw Pitch Count: 19
# Pitcher: Kershaw Pitch Count: 19
# Pitcher: Kershaw Pitch Count: 20
# Pitcher: Peacock Pitch Count: 9
# Pitcher: Peacock Pitch Count: 10
# Pitcher: Peacock Pitch Count: 11
# Pitcher: Peacock Pitch Count: 11
# Pitcher: Peacock Pitch Count: 120
# Pitcher: Peacock Pitch Count: 13
# Pitcher: Peacock Pitch Count: 130
# Pitcher: Peacock Pitch Count: 14
# Pitcher: Peacock Pitch Count: 15
# Pitcher: Peacock Pitch Count: 16
# Pitcher: Peacock Pitch Count: 17
# Pitcher: Peacock Pitch Count: 17
# Pitcher: Peacock Pitch Count: 18
# Pitcher: Peacock Pitch Count: 19
# Pitcher: Peacock Pitch Count: 20
# Pitcher: Kershaw Pitch Count: 220
# Pitcher: Kershaw Pitch Count: 23
# Pitcher: Kershaw Pitch Count: 24
# Pitcher: Kershaw Pitch Count: 24
# Pitcher: Kershaw Pitch Count: 25
# Pitcher: Kershaw Pitch Count: 26
# Pitcher: Kershaw Pitch Count: 27
# Pitcher: Kershaw Pitch Count: 28
# Pitcher: Kershaw Pitch Count:
# Pitcher: Kershaw Pitch Count: 30
# Pitcher: Peacock Pitch Count: 21
# Pitcher: Peacock Pitch Count: 220
# Pitcher: Peacock Pitch Count: 23
# Pitcher: Peacock Pitch Count: 24
# Pitcher: Peacock Pitch Count: 25
# Pitcher: Peacock Pitch Count: 26
# Pitcher: Peacock Pitch Count: 26
# Pitcher: Peacock Pitch Count: 27
# Pitcher: Peacock Pitch Count: 28
# Pitcher: Peacock Pitch Count: 29
# Pitcher: Peacock Pitch Count: 290
# Pitcher: Peacock Pitch Count: 30
# Pitcher: Peacock Pitch Count: 30
# Pitcher: Peacock Pitch Count: 31
# Pitcher: Peacock Pitch Count: 31
# Pitcher: Peacock Pitch Count: 320
# Pitcher: Peacock Pitch Count: 33
# Pitcher: Devenski Pitch Count: 1
# Pitcher: Peacock Pitch Count: 34
# Pitcher: Peacock Pitch Count: 34
# Pitcher: Peacock Pitch Count: 35
# Pitcher: Peacock Pitch Count: 35
# Pitcher: Peacock Pitch Count: 36
# Pitcher: Peacock Pitch Count: 37
# Pitcher: Peacock Pitch Count: 37
# Pitcher: Liriano Pitch Count: 1
# Pitcher: Liriano Pitch Count: 2
# Pitcher: Liriano Pitch Count: 3
# Pitcher: Liriano Pitch Count: 4
# Pitcher: Devenski Pitch Count: 1
# Pitcher: Devenski Pitch Count: 2
# Pitcher: Devenski Pitch Count: 3
# Pitcher: Devenski Pitch Count: 4
# Pitcher: Devenski Pitch Count: 4
# Pitcher: Devenski Pitch Count: 5
# Pitcher: Devenski Pitch Count: 5
# Pitcher: Devenski Pitch Count: 5
# Pitcher: Kershaw Pitch Count: 32
# Pitcher: Kershaw Pitch Count: 33
# Pitcher: Kershaw Pitch Count: 34
# Pitcher: Kershaw Pitch Count: 35
# Pitcher: Kershaw Pitch Count: 36
# Pitcher: Kershaw Pitch Count: 37
# Pitcher: Kershaw Pitch Count: 37
# Pitcher: Kershaw Pitch Count: 38
# Pitcher: Kershaw Pitch Count: 39
# Pitcher: Kershaw Pitch Count: 40
# Pitcher: Kershaw Pitch Count: 41
# Pitcher: Kershaw Pitch Count: 41
# Pitcher: Kershaw Pitch Count: 41
# Pitcher: Kershaw Pitch Count: 41
# Pitcher: Kershaw Pitch Count: 42
# Pitcher: Morton Pitch Count: 1
# Pitcher: Morton Pitch Count: 2
# Pitcher: Morton Pitch Count:
# Pitcher: Morton Pitch Count: 3
# Pitcher: Morton Pitch Count: 4
# Pitcher: Morton Pitch Count: 4
# Pitcher: Morton Pitch Count: 5
# Pitcher: Morton Pitch Count: 6
# Pitcher: Morton Pitch Count: 7
# Pitcher: Morton Pitch Count: 7
# Pitcher: Morton Pitch Count: 8
# Pitcher: Morton Pitch Count: 8
# Pitcher: Morton Pitch Count: 8
# Pitcher: Morton Pitch Count: 9
# Pitcher: Morton Pitch Count: 10
# Pitcher: Morton Pitch Count: 11
# Pitcher: Morton Pitch Count: 12
# Pitcher: Morton Pitch Count: 12
# Pitcher: Morton Pitch Count: 13
# Pitcher: Morton Pitch Count: 14
# Pitcher: Morton Pitch Count: 15
# Pitcher: Morton Pitch Count: 15
# Pitcher: Morton Pitch Count: 16
# Pitcher: Morton Pitch Count: 17
# Pitcher: Morton Pitch Count: 18
# Pitcher: Morton Pitch Count: 18
# Pitcher: Morton Pitch Count: 19
# Pitcher: Morton Pitch Count: 19
# Pitcher: Morton Pitch Count: 20
# Pitcher: Jansen Pitch Count: 1
# Pitcher: Jansen Pitch Count: 2
# Pitcher: Jansen Pitch Count: 3
# Pitcher: Jansen Pitch Count: 4
# Pitcher: Jansen Pitch Count: 4
# Pitcher: Jansen Pitch Count: 5
# Pitcher: Jansen Pitch Count: 5
# Pitcher: Jansen Pitch Count: 6
# Pitcher: Jansen Pitch Count: 7
# Pitcher: Jansen Pitch Count: 7
# Pitcher: Jansen Pitch Count: 8
# Pitcher: Jansen Pitch Count: 9
# Pitcher: Jansen Pitch Count: 10
# Pitcher: Jansen Pitch Count: 11
# Pitcher: Jansen Pitch Count: 12
# Pitcher: Jansen Pitch Count: 12
# Pitcher: Jansen Pitch Count: 13
# Pitcher: Jansen Pitch Count: 14
# Pitcher: Jansen Pitch Count: 150
# Pitcher: Jansen Pitch Count: 16
# Pitcher: Jansen Pitch Count: 17
# Pitcher: Jansen Pitch Count: 17
# Pitcher: Jansen Pitch Count: 18
# Pitcher: Jansen Pitch Count: 18
# Pitcher: Jansen Pitch Count: 19
# Pitcher: Jansen Pitch Count: 19
# Pitcher: Jansen Pitch Count:
# Pitcher: Morton Pitch Count: 20
# Pitcher: Morton Pitch Count: 21
# Pitcher: Morton Pitch Count: 220
# Pitcher: Morton Pitch Count: 23
# Pitcher: Morton Pitch Count: 23
# Pitcher: Morton Pitch Count: 24
# Pitcher: Morton Pitch Count: 24
# Pitcher: Morton Pitch Count: 25
# Pitcher: Morton Pitch Count: 25
# Pitcher: Morton Pitch Count: 26
# Pitcher: Morton Pitch Count: 27
# Pitcher: Morton Pitch Count: 28
# Pitcher: Morton Pitch Count: 28
# Pitcher: Morton Pitch Count: 290
# Pitcher: Morton Pitch Count: 30
# Pitcher: Wood Pitch Count: 1
# Pitcher: Wood Pitch Count: 2
# Pitcher: Wood Pitch Count: 3
# Pitcher: Wood Pitch Count: 3
# Pitcher: Wood Pitch Count: 4
# Pitcher: Wood Pitch Count: 5
# Pitcher: Wood Pitch Count: 6
# Pitcher: Wood Pitch Count: 6
# Pitcher: Wood Pitch Count: 7
# Pitcher: Wood Pitch Count: 8
# Pitcher: Wood Pitch Count: 9
# Pitcher: Wood Pitch Count: 10
# Pitcher: Wood Pitch Count: 11
# Pitcher: Wood Pitch Count: 11
# Pitcher: Wood Pitch Count: 120
# Pitcher: Wood Pitch Count: 13
# Pitcher: Morton Pitch Count: 31
# Pitcher: Morton Pitch Count: 320
# Pitcher: Morton Pitch Count: 33
# Pitcher: Morton Pitch Count: 34
# Pitcher: Morton Pitch Count: 34
# Pitcher: Morton Pitch Count: 35
# Pitcher: Morton Pitch Count: 36
# Pitcher: Morton Pitch Count: 37
# Pitcher: Morton Pitch Count: 37
# Pitcher: Morton Pitch Count: 38
# Pitcher: Morton Pitch Count: 39
# Pitcher: Morton Pitch Count: 40
# Pitcher: Morton Pitch Count: 41
# Pitcher: Morton Pitch Count: 420
# Pitcher: Wood Pitch Count: 15
# Pitcher: Wood Pitch Count: 160
# Pitcher: Wood Pitch Count: 17
# Pitcher: Wood Pitch Count: 18
# Pitcher: Wood Pitch Count: 19
# Pitcher: Wood Pitch Count: 20
# Pitcher: Wood Pitch Count: 21
# Pitcher: Wood Pitch Count: 220
# Pitcher: Wood Pitch Count: 220
# Pitcher: Wood Pitch Count: 23
# Pitcher: Wood Pitch Count: 24
# Pitcher: Morton Pitch Count: 43
# Pitcher: Morton Pitch Count: 44
# Pitcher: Morton Pitch Count: 45
# Pitcher: Morton Pitch Count: 46
# Pitcher: Morton Pitch Count: 46
# Pitcher: Morton Pitch Count: 47
# Pitcher: Morton Pitch Count: 48
# Pitcher: Morton Pitch Count: 49
# Pitcher: Morton Pitch Count: 49
# Pitcher: Morton Pitch Count: 50
# Pitcher: Morton Pitch Count: 51
# Wall time: 33min 17s

# %% [markdown]
# game 2 processing time 6.15.20 45min 38s
#
# ''  '' processing time 6.16.20 22min 49s
#
# after each game is collected certain by hand corrections are going to be run through.
#
# 1) Tesseract is not perfect, names will be close but not accurate everytime, for instance when collecting game 2, It found the pitcher Keal's name to be Kea. Similarly the numbers can be misread from time to time.
#
# 2) false postive timestamps. Simply remove these.
#
# I have pitch logs pulled from the baseball savant website, the information pulled by tesseract is to match the timestamp pulled from the game to the pitch outcome. Therefore I have a cross reference to correct the misreads by Tesseract. I.e I know the closer was named Keal not Kea, or how many pitches each pitcher threw.
#
# These actions are continued in the log joiner program
