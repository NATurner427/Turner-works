# %% [markdown]
# ## Spectrogram maker
#
# I've now collected the relevant pitch audio clips and need to convert them into spectrograms so a CNN can perform visual recogniton practiced on a whip-poor-will birdcall and fine tuned parameters and became familiar with the libraries I would be using. Use the reference Efremova et al 2019 IEEE for processing parameters.

# %%
from pydub import AudioSegment
from scipy import signal
from scipy.io import wavfile
import moviepy.editor as mpy
from pydub.playback import play

from PIL import Image

import gc
import os
import cv2
import scipy.misc
import numpy as np
import pandas as pd
from sklearn.preprocessing import normalize

import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.colors as colors

from IPython.display import clear_output

# %matplotlib inline

# %%
from pydub import AudioSegment
from scipy import signal
from scipy.io import wavfile
import moviepy.editor as mpy
from pydub.playback import play

from PIL import Image

import gc
import os
import cv2
import scipy.misc
import numpy as np
import pandas as pd
from sklearn.preprocessing import normalize

import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.colors as colors

from IPython.display import clear_output

# %matplotlib inline

#GAMES SUMMARY
summary=pd.read_csv('E://HOU18/HOU_18_games.csv')
"""
"""
n=169

#GAME LOG

path=(f'E://HOU18/games/game {n}/')

game=pd.read_csv(f'E://HOU18/games/game {n}/pitch outcomes and time.csv')
print(len(game))
opp=summary['Opponent'][n-1]

#LOOP ITERATOR
x=0

#RESOLUTION OF IMAGES
my_dpi=150

while x < len(game):

    file_name=(f"{game['game_pitch'].values[x]} {opp} {game['pitcher'].values[x]} pitch #{game['pitch_count'].values[x]} - {game['pitch_type'].values[x]}")

    #CONVERT STEREO TO MONO
    sound=AudioSegment.from_wav(f'{path}audio clips/{file_name}.wav')
    sound=sound.set_channels(1)
    sound=sound.set_frame_rate(22050)

    #EXPORT MONO FOR FUTURE REFERENCE
    sound.export(f'{path}audio clips/{file_name}.wav',format='wav')

    #PULL IN AND UNPACK MONO WAV FILE
    sample_rate, samples = wavfile.read(f'{path}audio clips/{file_name}.wav')

    #CALCULATE AND UNPACK SPECTROGRAM 
    freq,times,spectro=signal.spectrogram(samples, sample_rate,window='hamming',nperseg=1024,noverlap=896,scaling='density')

    #CONVERT TO dB and scale from 0 to 255
    dB=np.log(1+(spectro))
    scale=255/dB.max()
    dB=dB*scale

    # CREATE SPECTROGRAM AND EXPORT
    fig=plt.figure(figsize=(1280/my_dpi,720/my_dpi),frameon=False,dpi=my_dpi)
    ax=plt.Axes(fig, [0,0,1,1])
    ax.set_ylim(ymin=0,ymax=8000)
    ax.set_axis_off()
    fig.add_axes(ax)
    ax.pcolormesh(times,freq,dB,vmin=0,cmap='bone')
    fig.savefig(f'{path}spectrograms/{file_name}.tiff')
    plt.close()

    gc.collect()
    clear_output(wait=True)
    x+=1
print('done')
# Out:
# done

# %%
# %%time

#GAMES SUMMARY
summary=pd.read_csv('E://HOU18/Playoffs 2017/2017playoff_games.csv')

# GAME NUMBER
n=16

#GAME LOG
game=pd.read_csv(f'E://HOU18/Playoffs 2017/games/game {n}/pitch outcomes and time.csv')
print(len(game))
opp=summary['Opponent'][n-1]

#LOOP ITERATOR
x=0

#RESOLUTION OF IMAGES
my_dpi=150

path=(f'E://HOU18/Playoffs 2017/games/game {n}/')
        
while x < len(game):

    file_name=(f"{game['game_pitch'].values[x]} {opp} {game['pitcher'].values[x]} pitch #{game['pitch_count'].values[x]} - {game['pitch_type'].values[x]}")

    #CONVERT STEREO TO MONO
    sound=AudioSegment.from_wav(f'{path}audio clips/{file_name}.wav')
    sound=sound.set_channels(1)
    sound=sound.set_frame_rate(22050)

    #EXPORT MONO FOR FUTURE REFERENCE
    sound.export(f'{path}audio clips/{file_name}.wav',format='wav')

    #PULL IN AND UNPACK MONO WAV FILE
    sample_rate, samples = wavfile.read(f'{path}audio clips/{file_name}.wav')

    #CALCULATE AND UNPACK SPECTROGRAM 
    freq,times,spectro=signal.spectrogram(samples, sample_rate,window='hamming',nperseg=1024,noverlap=896,scaling='density')

    #CONVERT TO dB and scale from 0 to 255
    dB=np.log(1+(spectro))
    scale=255/dB.max()
    dB=dB*scale

    # CREATE SPECTROGRAM AND EXPORT
    fig=plt.figure(figsize=(1280/my_dpi,720/my_dpi),frameon=False,dpi=my_dpi)
    ax=plt.Axes(fig, [0,0,1,1])
    ax.set_ylim(ymin=0,ymax=8000)
    ax.set_axis_off()
    fig.add_axes(ax)
    ax.pcolormesh(times,freq,dB,vmin=0,cmap='bone')
    fig.savefig(f'{path}spectrograms/{file_name}.tiff')
    plt.close()

    gc.collect()
    clear_output(wait=True)
    x+=1
# Out:
# Wall time: 5min 16s

# %% [markdown]
# ## SINGLE SPECTROGRAM

# %%
# %matplotlib inline

# make mono
sound=AudioSegment.from_wav('C://Users/16142/Desktop/macandme.wav')
sound=sound.set_channels(1)
sound=sound.set_frame_rate(22050)

#EXPORT MONO FOR FUTURE REFERENCE
sound.export('C://Users/16142/Desktop/macandme.wav',format='wav')


sample_rate, samples = wavfile.read('C://Users/16142/Desktop/macandme.wav')

freq,times,spectro=signal.spectrogram(samples, sample_rate,window='hamming',nperseg=1024,noverlap=896,scaling='density')

#Process spectrogram so intensity is a value between 0 and 255
dB=np.log(1+(spectro))
scale=255/dB.max()
dB=dB*scale

my_dpi=150
fig=plt.figure(figsize=(1920/my_dpi,1080/my_dpi),frameon=False,dpi=my_dpi)
ax=plt.Axes(fig, [0,0,1,1])
ax.set_ylim(ymin=0,ymax=8000)
fig.add_axes(ax)
ax.pcolormesh(times,freq,dB,vmin=0,cmap='bone')
fig.savefig('C://Users/16142/Desktop/macandmetest.tiff')
